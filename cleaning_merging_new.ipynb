# %% [markdown]
# # Tracks dataset cleaning

# %%
import numpy as np
import pandas as pd

# sql alchemy for connecting to database
from sqlalchemy import create_engine, func
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import inspect
import sqlite3


import os

# %%
# read in tracks.csv
df_tracks = pd.read_csv('./tracks.csv')
print(df_tracks.shape)
df_tracks.head(10)
# Out:
# (586672, 20)
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                            Ave Maria           0
# 6  0Dd9ImXtAtGwsmsAD69KZT                       La Butte Rouge           0
# 7  0IA0Hju8CAgYfV1hwhidBH                              La Java           0
# 8  0IgI1UCz84pYeVetnl1lGP                   Old Fashioned Girl           0
# 9  0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
# 5       178933         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
# 6       134467         0    ['Francis Marty']  ['2nuMRGzeJ5jJEKlfS7rZ0W']
# 7       161427         0      ['Mistinguett']  ['4AxgXfD7ISvJSTObqm4aIE']
# 8       310073         0      ['Greg Fieler']  ['5nWlsH5RDgFuRAiDeOFVmf']
# 9       181173         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
# 5         1922         0.227  0.2610    5   -12.343     1       0.0382
# 6         1922         0.510  0.3550    4   -12.833     1       0.1240
# 7         1922         0.563  0.1840    4   -13.757     1       0.0512
# 8         1922         0.488  0.4750    0   -16.222     0       0.0399
# 9   1922-03-29         0.548  0.0391    6   -23.228     1       0.1530
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674          0.744000    0.1510   0.1270  104.851               3
# 1         0.797          0.000000    0.1480   0.6550  102.009               1
# 2         0.994          0.021800    0.2120   0.4570  130.418               5
# 3         0.995          0.918000    0.1040   0.3970  169.980               3
# 4         0.989          0.130000    0.3110   0.1960  103.220               4
# 5         0.994          0.247000    0.0977   0.0539  118.891               4
# 6         0.965          0.000000    0.1550   0.7270   85.754               5
# 7         0.993          0.000016    0.3250   0.6540  133.088               3
# 8         0.620          0.006450    0.1070   0.5440  139.952               4
# 9         0.996          0.933000    0.1480   0.6120   75.595               3

# %%
# strip extra brackets and single quotes from artists column
df_tracks['artists'] = df_tracks['artists'].str.strip("['']")

# %%
# strip extra brackets and single quotes from id_artists column
df_tracks['id_artists'] = df_tracks['id_artists'].str.strip("['']")

# %%
# get first artists only and replace in df
featured_index = df_tracks[df_tracks['artists'].str.contains(',')].index
multiple_artists = df_tracks[df_tracks['artists'].str.contains(',')]
first_artists = multiple_artists['artists'].str.extract(r'((\w*\s)*\w*)\'\,')[0]
df_tracks.loc[df_tracks['artists'].str.contains(','),'artists'] = first_artists

# %%
# do the same for artists id 
multiple_id = df_tracks[df_tracks['id_artists'].str.contains(',')]
first_id = df_tracks['id_artists'].str.extract(r'(\w*)\'\,')[0]
df_tracks.loc[df_tracks['id_artists'].str.contains(','),'id_artists'] = first_id

# %%
df_tracks.dropna(inplace=True)
df_tracks['release_date'] = df_tracks['release_date'].str.extract(r'(\d{4})')[0]

# %%
df_tracks['release_date'] = df_tracks['release_date'].astype(int)

# %%
# bin the release_date by decade and place in a list. Append list to dataframe
bin = [1899, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020,2030]
group_decade = ["1900's", "1910's","1920's","1930's","1940's","1950's","1960's","1970's","1980's","1990's","2000's","2010's","2020's"]

df_tracks['decades'] = pd.cut(df_tracks['release_date'], bin, labels=group_decade)

# %%
# drop time_signature ==0 or 1
df_tracks.drop(df_tracks[(df_tracks['time_signature'] == 0) | (df_tracks['time_signature'] == 1)].index, inplace=True)

# %%
# reset index and print cleaned dataframe
df_tracks.reset_index(drop=True, inplace=True)
df_tracks.head(10)
# Out:
#                        id                                name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                               Carve           6
# 1  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado           0
# 2  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado           0
# 3  08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening           0
# 4  0BRXJHRNGQ3W4v9frnSfhu                           Ave Maria           0
# 5  0Dd9ImXtAtGwsmsAD69KZT                      La Butte Rouge           0
# 6  0IA0Hju8CAgYfV1hwhidBH                             La Java           0
# 7  0IgI1UCz84pYeVetnl1lGP                  Old Fashioned Girl           0
# 8  0JV4iqw2lSKJaHBQZ0e5zK       Martín Fierro - Remasterizado           0
# 9  0OYGe21oScKJfanLyM7daU  Capítulo 2.8 - Banquero Anarquista           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 2       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
# 4       178933         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
# 5       134467         0    Francis Marty  2nuMRGzeJ5jJEKlfS7rZ0W
# 6       161427         0      Mistinguett  4AxgXfD7ISvJSTObqm4aIE
# 7       310073         0      Greg Fieler  5nWlsH5RDgFuRAiDeOFVmf
# 8       181173         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 9        99100         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
#
#    release_date  danceability  energy  ...  loudness  mode  speechiness  \
# 0          1922         0.645  0.4450  ...   -13.338     1       0.4510
# 1          1922         0.434  0.1770  ...   -21.180     1       0.0512
# 2          1922         0.321  0.0946  ...   -27.961     1       0.0504
# 3          1922         0.402  0.1580  ...   -16.900     0       0.0390
# 4          1922         0.227  0.2610  ...   -12.343     1       0.0382
# 5          1922         0.510  0.3550  ...   -12.833     1       0.1240
# 6          1922         0.563  0.1840  ...   -13.757     1       0.0512
# 7          1922         0.488  0.4750  ...   -16.222     0       0.0399
# 8          1922         0.548  0.0391  ...   -23.228     1       0.1530
# 9          1922         0.676  0.2350  ...   -22.447     0       0.9600
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0         0.674          0.744000    0.1510   0.1270  104.851               3
# 1         0.994          0.021800    0.2120   0.4570  130.418               5
# 2         0.995          0.918000    0.1040   0.3970  169.980               3
# 3         0.989          0.130000    0.3110   0.1960  103.220               4
# 4         0.994          0.247000    0.0977   0.0539  118.891               4
# 5         0.965          0.000000    0.1550   0.7270   85.754               5
# 6         0.993          0.000016    0.3250   0.6540  133.088               3
# 7         0.620          0.006450    0.1070   0.5440  139.952               4
# 8         0.996          0.933000    0.1480   0.6120   75.595               3
# 9         0.794          0.000000    0.2100   0.7240   96.777               3
#
#    decades
# 0   1920's
# 1   1920's
# 2   1920's
# 3   1920's
# 4   1920's
# 5   1920's
# 6   1920's
# 7   1920's
# 8   1920's
# 9   1920's
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Artists dataset cleaning

# %%
# read in artists.csv 
file_path = './artists.csv'
df_artists = pd.read_csv(file_path)
df_artists
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# 2                                                 Sadaa           0
# 3                                             Tra'gruda           0
# 4                                Ioannis Panoutsopoulos           0
# ...                                                 ...         ...
# 1104344                                      Cody Longo           8
# 1104345                                 Right the Stars          18
# 1104346                                  Jesse Giddings           0
# 1104347                            The Boy Band Project           0
# 1104348                                      10 Reasons           1
#
# [1104349 rows x 5 columns]

# %%
# remove all empty genres
df_artists = df_artists[df_artists['genres'] != '[]']
df_artists.head()
# Out:
#                          id  followers                      genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2       71.0          ['carnaval cadiz']
# 46   0dt23bs4w8zx154C5xdVyl       63.0          ['carnaval cadiz']
# 47   0pGhoB99qpEJEsBQxgaskQ       64.0          ['carnaval cadiz']
# 48   3HDrX2OtSuXLW5dLR85uN3       53.0          ['carnaval cadiz']
# 136  22mLrN5fkppmuUPsHx6i2G       59.0  ['classical harp', 'harp']
#
#                              name  popularity
# 45   Las Viudas De Los Bisabuelos           6
# 46              Los De Capuchinos           5
# 47             Los “Pofesionales”           7
# 48      Los Que No Paran De Rajar           6
# 136                   Vera Dulova           3

# %%
# convert genres column into a list datatype
df_artists['genres'] = df_artists['genres'].apply(eval)
df_artists.head()
# Out:
# <ipython-input-15-d7974bac8c18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_artists['genres'] = df_artists['genres'].apply(eval)
#                          id  followers                  genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2       71.0        [carnaval cadiz]
# 46   0dt23bs4w8zx154C5xdVyl       63.0        [carnaval cadiz]
# 47   0pGhoB99qpEJEsBQxgaskQ       64.0        [carnaval cadiz]
# 48   3HDrX2OtSuXLW5dLR85uN3       53.0        [carnaval cadiz]
# 136  22mLrN5fkppmuUPsHx6i2G       59.0  [classical harp, harp]
#
#                              name  popularity
# 45   Las Viudas De Los Bisabuelos           6
# 46              Los De Capuchinos           5
# 47             Los “Pofesionales”           7
# 48      Los Que No Paran De Rajar           6
# 136                   Vera Dulova           3

# %%
# reset index and print cleaned dataframe
df_artists.reset_index(drop=True, inplace=True)
df_artists.head()
# Out:
#                        id  followers                  genres  \
# 0  0VLMVnVbJyJ4oyZs2L3Yl2       71.0        [carnaval cadiz]
# 1  0dt23bs4w8zx154C5xdVyl       63.0        [carnaval cadiz]
# 2  0pGhoB99qpEJEsBQxgaskQ       64.0        [carnaval cadiz]
# 3  3HDrX2OtSuXLW5dLR85uN3       53.0        [carnaval cadiz]
# 4  22mLrN5fkppmuUPsHx6i2G       59.0  [classical harp, harp]
#
#                            name  popularity
# 0  Las Viudas De Los Bisabuelos           6
# 1             Los De Capuchinos           5
# 2            Los “Pofesionales”           7
# 3     Los Que No Paran De Rajar           6
# 4                   Vera Dulova           3

# %%
# check that conversion worked
print(type(df_artists.loc[0,'genres']))
# Out:
# <class 'list'>

# %%
# define function to create a series of value counts for unique genres
def unique_values(series):
    return pd.Series([x for _list in series for x in _list])

# %%
# apply function to genres column in artists dataframe
unique = unique_values(df_artists['genres']).value_counts()
unique
# Out:
# dance pop                572
# pop                      568
# rock                     564
# electro house            558
# classical performance    502
#                         ...
# musica puntana             3
# himene tarava              2
# mazandarani folk           2
# musica timor-leste         2
# swazi traditional          1
# Length: 5365, dtype: int64

# %%
# create values columns
unique = pd.Series(unique, name="values")
unique
# Out:
# dance pop                572
# pop                      568
# rock                     564
# electro house            558
# classical performance    502
#                         ...
# musica puntana             3
# himene tarava              2
# mazandarani folk           2
# musica timor-leste         2
# swazi traditional          1
# Name: values, Length: 5365, dtype: int64

# %%
# create unique genres dataframe
unique_df = pd.DataFrame(unique)
unique_df.head()
# Out:
#                        values
# dance pop                 572
# pop                       568
# rock                      564
# electro house             558
# classical performance     502

# %%
# format unique dataframe
unique_df.reset_index(inplace=True)
unique_df.rename(columns={'index': 'genres'}, inplace=True)
unique_df.head()
# Out:
#                   genres  values
# 0              dance pop     572
# 1                    pop     568
# 2                   rock     564
# 3          electro house     558
# 4  classical performance     502

# %%
# explode genres column in artists dataframe to get individual row per song genre
df_artists = df_artists.explode('genres')
df_artists.head()
# Out:
#                        id  followers          genres  \
# 0  0VLMVnVbJyJ4oyZs2L3Yl2       71.0  carnaval cadiz
# 1  0dt23bs4w8zx154C5xdVyl       63.0  carnaval cadiz
# 2  0pGhoB99qpEJEsBQxgaskQ       64.0  carnaval cadiz
# 3  3HDrX2OtSuXLW5dLR85uN3       53.0  carnaval cadiz
# 4  22mLrN5fkppmuUPsHx6i2G       59.0  classical harp
#
#                            name  popularity
# 0  Las Viudas De Los Bisabuelos           6
# 1             Los De Capuchinos           5
# 2            Los “Pofesionales”           7
# 3     Los Que No Paran De Rajar           6
# 4                   Vera Dulova           3

# %%
# merge artists and unqiue genres dataframes to get value counts
df_artists = df_artists.merge(unique_df, how='left', on='genres')
df_artists.head()
# Out:
#                        id  followers          genres  \
# 0  0VLMVnVbJyJ4oyZs2L3Yl2       71.0  carnaval cadiz
# 1  0dt23bs4w8zx154C5xdVyl       63.0  carnaval cadiz
# 2  0pGhoB99qpEJEsBQxgaskQ       64.0  carnaval cadiz
# 3  3HDrX2OtSuXLW5dLR85uN3       53.0  carnaval cadiz
# 4  22mLrN5fkppmuUPsHx6i2G       59.0  classical harp
#
#                            name  popularity  values
# 0  Las Viudas De Los Bisabuelos           6      69
# 1             Los De Capuchinos           5      69
# 2            Los “Pofesionales”           7      69
# 3     Los Que No Paran De Rajar           6      69
# 4                   Vera Dulova           3      82

# %%
# sort values column in ascending order
df_artists.sort_values(by=['values'], inplace=True)
df_artists.head()
# Out:
#                             id  followers              genres  \
# 185854  05YcBmsjblLBb6oROMrwqF       78.0   swazi traditional
# 382469  72PYDG3xLIxeRagDWDcss6       29.0       himene tarava
# 360254  43gNFp9nIKgWbu8DNz24Nc        8.0       himene tarava
# 324978  4WsBfMeAqIoAiHK7n80ydX      146.0    mazandarani folk
# 322797  6ZU1htIEHw1tA3VzHcgiJl       90.0  musica timor-leste
#
#                        name  popularity  values
# 185854   Ipelegeng Ensemble          19       1
# 382469         Tubuai Choir           0       2
# 360254        Himene Tarava           0       2
# 324978  Fereydoon Pour Reza           1       2
# 322797    The Dili Allstars           3       2

# %%
# drop duplicates in id column and only keep last occurance (highest value)
df_artists.drop_duplicates(['id'], keep='last', inplace=True)
df_artists.head()
# Out:
#                             id  followers              genres  \
# 360254  43gNFp9nIKgWbu8DNz24Nc        8.0       himene tarava
# 324978  4WsBfMeAqIoAiHK7n80ydX      146.0    mazandarani folk
# 322797  6ZU1htIEHw1tA3VzHcgiJl       90.0  musica timor-leste
# 272075  0MWnEq4x3G8ktrdN1tPEeX      141.0  musica timor-leste
# 239259  2OOTxuWRlzN2BQMvOfpolB       32.0    mazandarani folk
#
#                                                      name  popularity  values
# 360254                                      Himene Tarava           0       2
# 324978                                Fereydoon Pour Reza           1       2
# 322797                                  The Dili Allstars           3       2
# 272075                                          Ego Lemos           2       2
# 239259  Abolhasan Khoshru (Avaz & Desarkotan), Abdolla...           0       2

# %%
# drop to values column in the artists dataframe
df_artists.drop(columns=['values'], inplace=True)
df_artists.head()
# Out:
#                             id  followers              genres  \
# 360254  43gNFp9nIKgWbu8DNz24Nc        8.0       himene tarava
# 324978  4WsBfMeAqIoAiHK7n80ydX      146.0    mazandarani folk
# 322797  6ZU1htIEHw1tA3VzHcgiJl       90.0  musica timor-leste
# 272075  0MWnEq4x3G8ktrdN1tPEeX      141.0  musica timor-leste
# 239259  2OOTxuWRlzN2BQMvOfpolB       32.0    mazandarani folk
#
#                                                      name  popularity
# 360254                                      Himene Tarava           0
# 324978                                Fereydoon Pour Reza           1
# 322797                                  The Dili Allstars           3
# 272075                                          Ego Lemos           2
# 239259  Abolhasan Khoshru (Avaz & Desarkotan), Abdolla...           0

# %%
# reset the index 
df_artists.reset_index(drop=True, inplace=True)
df_artists.head()
# Out:
#                        id  followers              genres  \
# 0  43gNFp9nIKgWbu8DNz24Nc        8.0       himene tarava
# 1  4WsBfMeAqIoAiHK7n80ydX      146.0    mazandarani folk
# 2  6ZU1htIEHw1tA3VzHcgiJl       90.0  musica timor-leste
# 3  0MWnEq4x3G8ktrdN1tPEeX      141.0  musica timor-leste
# 4  2OOTxuWRlzN2BQMvOfpolB       32.0    mazandarani folk
#
#                                                 name  popularity
# 0                                      Himene Tarava           0
# 1                                Fereydoon Pour Reza           1
# 2                                  The Dili Allstars           3
# 3                                          Ego Lemos           2
# 4  Abolhasan Khoshru (Avaz & Desarkotan), Abdolla...           0

# %%
# create engine and connect to the spotify database
engine = create_engine("sqlite:///spotify_db.db")

# map the tables to objects
orm = automap_base()
orm.prepare(engine, reflect=True)
inspector = inspect(engine)

# %%
# check for existing tables in the database
inspector.get_table_names()
# Out:
# []

# %%
# create artists table in sqlite database
engine.execute('''
CREATE TABLE artists (
     id VARCHAR(22) NOT NULL,
     followers INT,
	 genres VARCHAR(317),
	 name VARCHAR(194) NOT NULL,
	 popularity INT,
     PRIMARY KEY (id))
     ''')

# %%
# create tracks table in sqlite database
engine.execute('''
CREATE TABLE tracks (
	 id VARCHAR(22),
	 name VARCHAR(529),
	 popularity INT,
	 duration_ms INT,
	 explicit INT,
	 artists VARCHAR(100), 
	 id_artists VARCHAR(22),
	 release_date VARCHAR(4),
	 danceability REAL,
	 energy REAL,
	 key INT,
	 loudness REAL,
	 mode INT,
	 speechiness REAL,
	 acousticness REAL,
	 instrumentalness REAL,
	 liveness REAL,
	 valence REAL,
	 tempo REAL,
	 time_signature INT,
	 decades VARCHAR(6),
     PRIMARY KEY (id))
     ''')

# %%
# check for artists columns and table schema
columns = inspector.get_columns('artists')
for column in columns:
    print(column)
# Out:
# {'name': 'id', 'type': VARCHAR(length=22), 'nullable': False, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'followers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'genres', 'type': VARCHAR(length=317), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'name', 'type': VARCHAR(length=194), 'nullable': False, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'popularity', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
# check for tracks columns and table schema
columns = inspector.get_columns('tracks')
for column in columns:
    print(column)
# Out:
# {'name': 'id', 'type': VARCHAR(length=22), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'name', 'type': VARCHAR(length=529), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'popularity', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'duration_ms', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'explicit', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'artists', 'type': VARCHAR(length=100), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'id_artists', 'type': VARCHAR(length=22), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'release_date', 'type': VARCHAR(length=4), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'danceability', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'energy', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'key', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'loudness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'mode', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'speechiness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'acousticness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'instrumentalness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'liveness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'valence', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'tempo', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'time_signature', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'decades', 'type': VARCHAR(length=6), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
# write df_tracks to tracks table in spotify database
df_tracks.to_sql('tracks', engine, if_exists='append', index = False, chunksize=100)

# %%
# write df_artists to artists table in spotify database
df_artists.to_sql('artists', engine, if_exists='append', index = False, chunksize=100)

# %%
conn = sqlite3.connect("spotify_db.db")
cursor = conn.cursor()

# %%
cursor.execute('''
CREATE TABLE master (
	 id VARCHAR(22),
	 name VARCHAR(529),
	 popularity INT,
	 duration_ms INT,
	 explicit INT,
	 artists VARCHAR(100), 
	 id_artists VARCHAR(22),
	 release_date VARCHAR(4),
	 danceability REAL,
	 energy REAL,
	 key INT,
	 loudness REAL,
	 mode INT,
	 speechiness REAL,
	 acousticness REAL,
	 instrumentalness REAL,
	 liveness REAL,
	 valence REAL,
	 tempo REAL,
	 time_signature INT,
	 decades VARCHAR(6),
	 followers INT,
	 genres VARCHAR(317),
	 PRIMARY KEY (id, id_artists))
     ''')

# %%
cursor.execute("""INSERT INTO master SELECT A.id, A.name, A.popularity, A.duration_ms,A.explicit, A.artists, A.id_artists, 
           A.release_date, A.danceability, A.energy, A.key, A.loudness, A.mode, A.speechiness, A.acousticness, 
           A.instrumentalness, A.liveness, A.valence, A.tempo, A.time_signature, A.decades, B.followers, B.genres 
           FROM tracks A
           INNER JOIN artists B 
           ON A.id_artists=B.id""")       

conn.commit()

# %%
inspector.get_table_names()
# Out:
# []

# %%
# check for master columns and table schema
columns = inspector.get_columns('master')
for column in columns:
    print(column)
# Out:
# {'name': 'id', 'type': VARCHAR(length=22), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'name', 'type': VARCHAR(length=529), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'popularity', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'duration_ms', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'explicit', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'artists', 'type': VARCHAR(length=100), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'id_artists', 'type': VARCHAR(length=22), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 2}
# {'name': 'release_date', 'type': VARCHAR(length=4), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'danceability', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'energy', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'key', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'loudness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'mode', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'speechiness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'acousticness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'instrumentalness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'liveness', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'valence', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'tempo', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'time_signature', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'decades', 'type': VARCHAR(length=6), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'followers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'genres', 'type': VARCHAR(length=317), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
master_df = pd.read_sql_query("SELECT * FROM master", conn)

# %%
master_df
# Out:
#                             id                                name  \
# 0       07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 1       08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 2       08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening
# 3       0BRXJHRNGQ3W4v9frnSfhu                           Ave Maria
# 4       0IA0Hju8CAgYfV1hwhidBH                             La Java
# ...                        ...                                 ...
# 518666  5rgu12WBIHQtvej2MdHSH0                                 云与海
# 518667  0NuWgxEp51CutD2pJoF4OM                               blind
# 518668  27Y1N4Q4U3EfDU5Ubw8ws2           What They'll Say About Us
# 518669  45XJsGpFTyzbzeWK8VzR8S                     A Day At A Time
# 518670  5Ocn6dZ3BJFPWh4ylwFXtn                    Mar de Emociones
#
#         popularity  duration_ms  explicit          artists  \
# 0                0       181640         0  Ignacio Corsini
# 1                0       176907         0  Ignacio Corsini
# 2                0       163080         0      Dick Haymes
# 3                0       178933         0      Dick Haymes
# 4                0       161427         0      Mistinguett
# ...            ...          ...       ...              ...
# 518666          50       258267         0          阿YueYue
# 518667          72       153293         0       ROLE MODEL
# 518668          70       187601         0          FINNEAS
# 518669          58       142003         0     Gentle Bones
# 518670          38       214360         0        Afrosound
#
#                     id_artists release_date  danceability  energy  ...  \
# 0       5LiOoJbxVSAMkBS2fUm3X2         1922         0.434  0.1770  ...
# 1       5LiOoJbxVSAMkBS2fUm3X2         1922         0.321  0.0946  ...
# 2       3BiJGZsyX9sJchTqcSA7Su         1922         0.402  0.1580  ...
# 3       3BiJGZsyX9sJchTqcSA7Su         1922         0.227  0.2610  ...
# 4       4AxgXfD7ISvJSTObqm4aIE         1922         0.563  0.1840  ...
# ...                        ...          ...           ...     ...  ...
# 518666  1QLBXKM5GCpyQQSVMNZqrZ         2020         0.560  0.5180  ...
# 518667  1dy5WNgIKQU6ezkpZs4y8z         2020         0.765  0.6630  ...
# 518668  37M5pPGs6V1fchFJSgCguX         2020         0.535  0.3140  ...
# 518669  4jGPdu95icCKVF31CcFKbS         2021         0.696  0.6150  ...
# 518670  0i4Qda0k4nf7jnNHmSNpYv         2015         0.686  0.7230  ...
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 0            0.0512         0.994          0.021800    0.2120   0.4570
# 1            0.0504         0.995          0.918000    0.1040   0.3970
# 2            0.0390         0.989          0.130000    0.3110   0.1960
# 3            0.0382         0.994          0.247000    0.0977   0.0539
# 4            0.0512         0.993          0.000016    0.3250   0.6540
# ...             ...           ...               ...       ...      ...
# 518666       0.0292         0.785          0.000000    0.0648   0.2110
# 518667       0.0652         0.141          0.000297    0.0924   0.6860
# 518668       0.0408         0.895          0.000150    0.0874   0.0663
# 518669       0.0345         0.206          0.000003    0.3050   0.4380
# 518670       0.0363         0.105          0.000000    0.2640   0.9750
#
#           tempo  time_signature  decades  followers             genres
# 0       130.418               5   1920's     3528.0              tango
# 1       169.980               3   1920's     3528.0              tango
# 2       103.220               4   1920's    11327.0    adult standards
# 3       118.891               4   1920's    11327.0    adult standards
# 4       133.088               3   1920's     5078.0    vintage chanson
# ...         ...             ...      ...        ...                ...
# 518666  131.896               4   2010's      896.0  chinese viral pop
# 518667  150.091               4   2010's   245944.0                pop
# 518668  145.095               4   2010's  1168213.0                pop
# 518669   90.029               4   2020's    45309.0     indie cafe pop
# 518670  112.204               4   2010's    19634.0             cumbia
#
# [518671 rows x 23 columns]
